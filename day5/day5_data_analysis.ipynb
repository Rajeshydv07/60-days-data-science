# %% [markdown]
# # Day 5 - Data Loading & Understanding
# Dataset: Sales Forecasting (Superstore)
#
# Target Variable: **Sales** (This is the variable we want to predict in a sales forecasting model)

# %%
import pandas as pd

# Note: Please ensure 'train.csv' (from the Kaggle dataset) is in the same directory
# For this notebook, we'll try to load 'train.csv'. 
try:
    df = pd.read_csv('train.csv')
    print("Dataset loaded successfully from local file!")
except FileNotFoundError:
    print("Error: 'train.csv' not found locally. Falling back to a sample online Superstore dataset.")
    # Fallback to a URL for demonstration purposes
    url = "https://raw.githubusercontent.com/plotly/datasets/master/superstore.csv"
    df = pd.read_csv(url, encoding='latin1')
    print("Loaded fallback dataset from URL.")

# %%
# 1. Print Shape
print("Shape of the dataset:", df.shape)

# %%
# 2. Print Columns
print("Columns in the dataset:")
print(df.columns.tolist())

# %%
# 3. Print Head
df.head()

# %% [markdown]
# ### Target Variable Identification
#
# In the context of **Sales Forecasting**, our primary goal is to predict future sales based on historical data.
#
# **Target Variable:** `Sales`
#
# Other potential target variables (depending on the specific business problem) could be `Profit` or `Quantity`.
