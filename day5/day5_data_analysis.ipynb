# %% [markdown]
# # Day 5: Data Loading and Understanding
# In this notebook, I am loading my sales dataset to understand its structure.

# %%
import pandas as pd

# loading the dataset
df = pd.read_csv('train.csv')

# %%
# checking the shape
print("Shape:", df.shape)

# %%
# checking all columns
print("Columns:", df.columns)

# %%
# showing first 5 rows
df.head()

# %% [markdown]
# ### Target Variable
# For my problem of forecasting sales, the target variable will be **Sales**.
